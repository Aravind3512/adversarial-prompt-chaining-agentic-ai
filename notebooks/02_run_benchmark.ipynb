# %% [markdown]
# # Run Benchmark

# %% [markdown]
# Run the deterministic route-first benchmark and inspect aggregate metrics.

# %%
from pathlib import Path
import sys
import pandas as pd

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT / 'src'))

from prompt_chaining_benchmark.runner import DEFAULT_RATIOS, run_experiment, save_outputs

# %%
tasks, states, metrics = run_experiment(DEFAULT_RATIOS, total_tasks=100, seed=6730)
output_dir = ROOT / 'results' / 'notebook_run'
save_outputs(tasks, states, metrics, output_dir)
print(f'Wrote outputs to {output_dir}')

# %%
df = pd.DataFrame(metrics)
cols = ['poison_ratio', 'poisoned_tasks', 'error_rate', 'asr_tool', 'asr_final', 'asr_strict', 'overall_failure_rate', 'benign_utility', 'avg_propagation_depth']
df[cols]
